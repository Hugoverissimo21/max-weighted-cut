# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

df = pd.read_excel("results.xlsx", header=[0,1], index_col=0)
df
# Out:
#                        Graph                Exhaustive            \
#                         name      n      m #operations exec_time
# 0    graphs/0004_125.graphml      4      0        68.0  0.000024
# 1    graphs/0004_250.graphml      4      1        70.0  0.000023
# 2    graphs/0004_500.graphml      4      3        74.0  0.000026
# 3    graphs/0004_750.graphml      4      4        72.0  0.000023
# 4    graphs/0005_125.graphml      5      1       199.0  0.000058
# ..                       ...    ...    ...         ...       ...
# 324                  gset/G7    800  19176         NaN       NaN
# 325                 gset/G70  10000   9999         NaN       NaN
# 326                 gset/G72  10000  20000         NaN       NaN
# 327                  gset/G8    800  19176         NaN       NaN
# 328                  gset/G9    800  19176         NaN       NaN
#
#                         Heuristic                              greedy_prec
# ...

# %% [markdown]
# # pop mean of greedy prec
#
# used mean +- z_value * sample_std / sqrt(len obs)

# %%
observations = df[("greedy_prec", " ")]

# Sample mean
sample_mean = observations.mean()

# Sample standard deviation
sample_std = observations.std()

# Sample size
n = len(observations)

# Calculate the 95% confidence interval
confidence_level = 0.95
z_value =stats.norm.ppf((1 + confidence_level) / 2)
margin_of_error = z_value * (sample_std / np.sqrt(n))

ci_lower = sample_mean - margin_of_error
ci_upper = sample_mean + margin_of_error

sample_mean, (ci_lower, ci_upper) # intervalo fechado
# Out:
# (np.float64(0.7875003385601443),
#  (np.float64(0.7630864792688177), np.float64(0.811914197851471)))

# %% [markdown]
# # graficos

# %%
n = df[("Graph", "n")]
ops_heuristic = df[("Heuristic", "#operations")]

for i in range(len(n)):
    if n[i] < 30 or False: #tlvz fazer log do numero de arestas ? para ficarem mais juntos ?
        plt.scatter(n[i], ops_heuristic[i])


x = np.linspace(0.1, 30, 100)
y = x**2 * np.log2(x)
plt.plot(x, y, label=r"$n^2 \cdot \log_2(n)$")
plt.legend()
plt.show()

# %%
n = df[("Graph", "n")]
ops_exhaustive= df[("Exhaustive", "#operations")]

for i in range(len(n)):
    if True: #tlvz fazer log do numero de arestas ? para ficarem mais juntos ?
        plt.scatter(n[i], ops_heuristic[i])


x = np.linspace(0.1, 24, 100)
y = x**2 * 2**(x-2)
plt.plot(x, y, label=r"$n^2 \cdot 2^{n-2}$") #-2 pq é o 2^n/2 * 2^n/2 q dá 2^n/4 = 2^n-4 , e como sobe muito rapido...
plt.legend()
plt.show()

# %%
# tentar juntar os dois graficos num so? idk, faziamos a janela do heuristico e dps deixamos o exaustivo mesmo sair e deixar de ser visto
